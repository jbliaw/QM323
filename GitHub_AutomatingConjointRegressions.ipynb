# %% [markdown]
# <a href="https://colab.research.google.com/github/jbliaw/QM323/blob/main/GitHub_AutomatingConjointRegressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install watermark

# %%
# %load_ext watermark

# %%
# %watermark
# Out:
# 2020-10-07T02:49:24+00:00
#
# CPython 3.6.9
# IPython 5.5.0
#
# compiler   : GCC 8.4.0
# system     : Linux
# release    : 4.19.112+
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 2
# interpreter: 64bit

# %% [markdown]
# - NOTE: Please make a copy of this file for yourself (it's like a google doc). That way you can edit as you need, and it won't interfere with other runs.
# - Before you start, prep the data for regression in excel (basically Conjoint Tutorial as posted in Conjoint Workshop QM 11 folder):
#      - transpose direct data from Qualtrics
#      - download "dummy variables for conjoint analysis regressions" on QTools
#      - copy and paste customers to "dummy variables..." excel file (see JetOrange example)
#      - rename file to 'conjointdata.xlsx' so that you can upload to Google Colab
# - Then upload the file:
#      - click folder icon to the left
#      - right click in white space (or regular click page with arrow icon) and upload 'conjointdata.xlsx'
#      - click each 'play'/run button (more instructions as #comments in each code block)

# %% [markdown]
# ## General Prep

# %%
from getpass import getpass
username = getpass('Username:')
password = getpass('Password:')
# Out:
# Username:··········
# Password:··········

# %%
# !if [ -d QM323 ]; then rm -Rf QM323; fi
# !git clone https://$username:$password@github.com/jbliaw/QM323.git
# !pip install ./QM323
# Out:
# Cloning into 'QM323'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.
# Processing ./QM323
# ...
#   Created wheel for not-DML: filename=not_DML-0.1.0-cp36-none-any.whl size=1007 sha256=25ffd0d32e872bb9b736f03093bdf77074e4ea53704363028f24e78c8039ece8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ecxg4pmh/wheels/e1/02/40/d3e1bdbb380378b139553229b569b0e5bde39f5c48baa084b8
# Successfully built not-DML
# ...

# %%
# Necessary imports
import pandas as pd
import pandas.testing as tm
import statsmodels.api as sm
import statsmodels.formula.api as smf
from QM323.Functions.automateregression import AutomateRegression

# %%
# Read in data
df = pd.read_excel('/content/QM323/conjointdata.xlsx')
print(df.shape) # (rows, columns)
df.head() # Take a look at the data
# Out:
# (9, 49)
#    Profile  Price high  Price low  ...  Customer41  Customer42  Customer43
# 0        1           1          0  ...           3           2           6
# 1        2           0          0  ...           2           2           3
# 2        3           0          0  ...           2           2           4
# 3        4           1          0  ...           3           2           3
# 4        5           1          0  ...           3           2           6
#
# [5 rows x 49 columns]

# %%
theresults = AutomateRegression.automateregression(df)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   "anyway, n=%i" % int(n))
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:1636: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   "anyway, n=%i" % int(n))
# /usr/local/lib/python3.6/dist-packages/scipy/stats/stats.py:1535: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=9
#   "anyway, n=%i" % int(n))
# /usr/local/lib/python3.6/dist-packages/statsmodels/regression/linear_model.py:1636: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# ...

# %%
theresults
# Out:
#     Intercept     pricehigh  ...  attribute3high  attribute4high
# 1      5.0000  2.220000e-16  ...    1.998000e-15    1.998000e-15
# 2      1.3333 -3.333000e-01  ...    3.333000e-01    6.667000e-01
# 3      5.0000  2.220000e-16  ...    1.998000e-15    1.998000e-15
# 4      6.0000  2.776000e-17  ...    2.665000e-15    1.998000e-15
# 5      4.6667 -1.666700e+00  ...    6.667000e-01   -6.667000e-01
# 6      2.3500 -1.500000e-01  ...    8.000000e-01    2.200000e+00
# 7      4.6667 -6.667000e-01  ...   -3.333000e-01   -1.666700e+00
# 8      2.5333 -1.333000e-01  ...    9.333000e-01   -9.333000e-01
# 9      3.2833  1.167000e-01  ...    1.933300e+00    6.670000e-02
# 10     3.2000 -3.300000e+00  ...    1.100000e+00   -1.000000e-01
# 11     1.0000  9.298000e-16  ...    1.305000e-15    5.551000e-16
# 12     5.0667  2.333000e-01  ...    8.667000e-01   -2.366700e+00
# 13     6.9000 -6.000000e-01  ...   -1.800000e+00    3.000000e-01
# ...

# %%
theresults.to_excel('conjointresults.xlsx')
